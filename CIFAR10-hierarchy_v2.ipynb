# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.utils import to_categorical
import tensorboard
import numpy as np
import logging
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd

# %%
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    try:
        tf.config.experimental.set_memory_growth(device, True)
    except:
        pass

logging.getLogger().setLevel(logging.INFO)

# %%
def get_cifar10():
    def create_superclass(x):
        return 0 if x in [0, 1, 8, 9] else 1
    v_create_superclass = np.vectorize(create_superclass)
    
    (x_train, y_sub_train), (x_test, y_sub_test) = keras.datasets.cifar10.load_data()
    x_train, x_test = x_train / 255, x_test / 255
    y_super_train, y_super_test = to_categorical(v_create_superclass(y_sub_train)), to_categorical(v_create_superclass(y_sub_test))
    y_sub_train, y_sub_test = to_categorical(y_sub_train), to_categorical(y_sub_test)
    
    return (x_train, y_super_train, y_sub_train), (x_test, y_super_test, y_sub_test)

# %%
def get_labels(idx, level = 'super'):
    labels = {
        'super':['machine', 'animal'],
        'sub': ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    }
    return labels[level][idx]

v_get_labels = np.vectorize(get_labels)

# %%
def plot_sample_images(inputs, v_label_func, top_n = 20, n_col = 10):
    (images, super_labels_idx, sub_labels_idx) = inputs
    assert len(images) == len(super_labels_idx) == len(sub_labels_idx)
    super_labels, sub_labels = v_label_func(np.argmax(super_labels_idx, axis = 1), 'super'),  v_label_func(np.argmax(sub_labels_idx, axis = 1), 'sub')
    top_n = top_n if top_n < len(images) else len(images)
    n_row = int(top_n/n_col)
    images = images[:top_n]
    figsize = (2.5 * n_col, 2.5 * n_row)
    fig, axes = plt.subplots(n_row, n_col, figsize = figsize)
    for idx, image in enumerate(images):
        ax = axes[idx // n_col, idx % n_col]
        ax.imshow(image)
        ax.set_title(f"{super_labels[idx]} - {sub_labels[idx]}")
    plt.tight_layout()
    plt.show()

# %%
(x_train, y_super_train, y_sub_train), (x_test, y_super_test, y_sub_test) = get_cifar10()
plot_sample_images((x_train, y_super_train, y_sub_train), v_get_labels)

# %%
def gen_hierarchy(super_label, sub_label, use_argmax = False):
    combined_labels = np.stack((np.argmax(super_label, axis = 1), np.argmax(sub_label, axis = 1)), axis = 1)
    unique_combinations = np.unique(combined_labels, axis = 0)
    hierarchy={}
    for combination in unique_combinations:
        super_class, sub_class = combination
        if super_class in hierarchy.keys():
            hierarchy[super_class].append(sub_class)
        else:
            hierarchy[super_class] = [sub_class]
    return hierarchy

# %%
def conv_block(units, kernel_size = (3,3), stride=(1, 1), dropout=0.2, activation='relu', block=1, layer=1, class_type='default'):

    def layer_wrapper(inp):
        x = Conv2D(units, kernel_size, padding='same', name=f'{class_type}_block{block}_conv{layer}')(inp)
        x = Activation(activation, name=f'{class_type}_block{block}_act{layer}')(x)
        x = Dropout(dropout, name=f'{class_type}_block{block}_dropout{layer}')(x)
        x = BatchNormalization(name=f'{class_type}_block{block}_bn{layer}')(x)
        return x
    return layer_wrapper

def dense_block(units, dropout=0.2, activation='relu', name='default_fc1'):
    def layer_wrapper(inp):
        x = Dense(units, name=name)(inp)
        x = BatchNormalization(name='{}_bn'.format(name))(x)
        x = Activation(activation, name='{}_act'.format(name))(x)
        x = Dropout(dropout, name='{}_dropout'.format(name))(x)
        return x
    return layer_wrapper



def create_base_layer(img_input, conv_dropout=0.1, fc_dropout=0.3, activation='relu', class_type = 'default'):
    
    # Block 1
    block = 1
    x = conv_block(32, kernel_size = (5, 5),dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(img_input)
    x = conv_block(32, kernel_size = (5, 5),dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)
    
    # Block 2
    block += 1
    x = conv_block(64, dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(x)
    x = conv_block(64, dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)

    # Block 3
    block += 1
    x = conv_block(128, dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(x)
    x = conv_block(128, dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)

    # Block 4
    block += 1
    x = conv_block(256, dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(x)
    x = conv_block(256, dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)

    x = GlobalAveragePooling2D()(x)
    
    # FC Layers
    x = dense_block(512, dropout=fc_dropout, activation=activation, name=f'{class_type}_fc1')(x)
    
    return x


def create_layer(img_input, n_classes, base_layer, conv_dropout=0.1, fc_dropout=0.3, activation='relu', class_type = 'default', embedding = None):
    x = dense_block(256, dropout=fc_dropout, activation=activation, name=f'{class_type}_fc2')(base_layer)
    x = dense_block(128, dropout=fc_dropout, activation=activation, name=f'{class_type}_fc3')(x)
    if embedding is not None:
        x = tf.keras.layers.Concatenate()([x, embedding])
    output = Dense(n_classes, activation='softmax', name=f'{class_type}_output')(x)
    return output, x

# %%
n_superclasses = 2
n_subclasses = 10
input_shape = x_train[0].shape

img_input = Input(shape=input_shape, name='input')

base_layer = create_base_layer(img_input,class_type = 'base')
super_layer, super_layer_embedding = create_layer(img_input, n_superclasses ,base_layer, class_type = 'super')
sub_layer,_ = create_layer(img_input, n_subclasses, base_layer, class_type = 'sub', embedding = super_layer_embedding)

model = keras.Model(inputs=img_input,
             outputs = [super_layer, sub_layer],
             name="cifar10")

# %%
init_lr = 1e-4
epochs = 65
super_weight_ratio = 0.4

opt = keras.optimizers.Adam(lr=init_lr, decay=init_lr / epochs)

model.compile(
    optimizer=opt,
    loss={
        'super_output':'categorical_crossentropy',
        'sub_output':'categorical_crossentropy'
    },
    metrics={
        'super_output':'accuracy',
        'sub_output':'accuracy'
    }, 
    loss_weights=[super_weight_ratio, 1 - super_weight_ratio]
)

# %%
# tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=False, show_dtype=False, show_layer_names=True, rankdir='TB', expand_nested=False)

# %%
logdir = "./logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")

# tensorboard_callback = keras.callbacks.TensorBoard(
#     log_dir=logdir,
#     histogram_freq=1
# )

# earlystop_callback = keras.callbacks.EarlyStopping(
#     monitor='val_loss', 
#     min_delta=1e-5,
#     patience=5
# )

# checkpoint_callbacks = [
#     keras.callbacks.ModelCheckpoint("./model_checkpoint", monitor='val_loss')
# ]

history = model.fit(
    x_train, 
    y={"super_output": y_super_train, "sub_output": y_sub_train},
    validation_data=(x_test,{"super_output": y_super_test, "sub_output": y_sub_test}),
    batch_size = 512,
    epochs=epochs,
    validation_split=0.2,
    use_multiprocessing=True,
#     callbacks=[
# #         tensorboard_callback,
#         earlystop_callback
#     ]
)
# Out:
# Epoch 1/65
# 79/79 [==============================] - 14s 88ms/step - loss: 1.7845 - super_output_loss: 0.6782 - sub_output_loss: 2.5221 - super_output_accuracy: 0.6531 - sub_output_accuracy: 0.1529 - val_loss: 1.8155 - val_super_output_loss: 0.8537 - val_sub_output_loss: 2.4566 - val_super_output_accuracy: 0.5947 - val_sub_output_accuracy: 0.0997
# Epoch 2/65
# 79/79 [==============================] - 5s 66ms/step - loss: 1.3883 - super_output_loss: 0.4097 - sub_output_loss: 2.0407 - super_output_accuracy: 0.8303 - sub_output_accuracy: 0.2701 - val_loss: 2.3311 - val_super_output_loss: 1.3957 - val_sub_output_loss: 2.9547 - val_super_output_accuracy: 0.5947 - val_sub_output_accuracy: 0.0997
# Epoch 3/65
# 79/79 [==============================] - 5s 66ms/step - loss: 1.2468 - super_output_loss: 0.3393 - sub_output_loss: 1.8518 - super_output_accuracy: 0.8610 - sub_output_accuracy: 0.3297 - val_loss: 2.4979 - val_super_output_loss: 1.3002 - val_sub_output_loss: 3.2965 - val_super_output_accuracy: 0.5947 - val_sub_output_accuracy: 0.0997
# Epoch 4/65
# 79/79 [==============================] - 5s 66ms/step - loss: 1.1636 - super_output_loss: 0.3073 - sub_output_loss: 1.7346 - super_output_accuracy: 0.8749 - sub_output_accuracy: 0.3674 - val_loss: 2.4280 - val_super_output_loss: 0.9973 - val_sub_output_loss: 3.3817 - val_super_output_accuracy: 0.5954 - val_sub_output_accuracy: 0.1003
# Epoch 5/65
# 79/79 [==============================] - 5s 66ms/step - loss: 1.1012 - super_output_loss: 0.2882 - sub_output_loss: 1.6432 - super_output_accuracy: 0.8861 - sub_output_accuracy: 0.4007 - val_loss: 2.2228 - val_super_output_loss: 0.7620 - val_sub_output_loss: 3.1967 - val_super_output_accuracy: 0.6411 - val_sub_output_accuracy: 0.1313
# Epoch 6/65
# 79/79 [==============================] - 5s 66ms/step - loss: 1.0555 - super_output_loss: 0.2703 - sub_output_loss: 1.5790 - super_output_accuracy: 0.8915 - sub_output_accuracy: 0.4227 - val_loss: 1.8313 - val_super_output_loss: 0.5334 - val_sub_output_loss: 2.6966 - val_super_output_accuracy: 0.7654 - val_sub_output_accuracy: 0.1979
# Epoch 7/65
# 79/79 [==============================] - 5s 69ms/step - loss: 1.0053 - super_output_loss: 0.2590 - sub_output_loss: 1.5029 - super_output_accuracy: 0.8971 - sub_output_accuracy: 0.4556 - val_loss: 1.6800 - val_super_output_loss: 0.4398 - val_sub_output_loss: 2.5068 - val_super_output_accuracy: 0.8123 - val_sub_output_accuracy: 0.2327
# Epoch 8/65
# 79/79 [==============================] - 5s 70ms/step - loss: 0.9619 - super_output_loss: 0.2418 - sub_output_loss: 1.4420 - super_output_accuracy: 0.9027 - sub_output_accuracy: 0.4715 - val_loss: 1.4230 - val_super_output_loss: 0.4101 - val_sub_output_loss: 2.0983 - val_super_output_accuracy: 0.8273 - val_sub_output_accuracy: 0.2933
# Epoch 9/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.9266 - super_output_loss: 0.2348 - sub_output_loss: 1.3879 - super_output_accuracy: 0.9075 - sub_output_accuracy: 0.4914 - val_loss: 1.2572 - val_super_output_loss: 0.3609 - val_sub_output_loss: 1.8547 - val_super_output_accuracy: 0.8438 - val_sub_output_accuracy: 0.3437
# Epoch 10/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.8972 - super_output_loss: 0.2295 - sub_output_loss: 1.3423 - super_output_accuracy: 0.9082 - sub_output_accuracy: 0.5125 - val_loss: 1.0968 - val_super_output_loss: 0.2788 - val_sub_output_loss: 1.6421 - val_super_output_accuracy: 0.8807 - val_sub_output_accuracy: 0.4038
# Epoch 11/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.8660 - super_output_loss: 0.2182 - sub_output_loss: 1.2979 - super_output_accuracy: 0.9154 - sub_output_accuracy: 0.5282 - val_loss: 1.0324 - val_super_output_loss: 0.2757 - val_sub_output_loss: 1.5368 - val_super_output_accuracy: 0.8840 - val_sub_output_accuracy: 0.4475
# Epoch 12/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.8364 - super_output_loss: 0.2081 - sub_output_loss: 1.2553 - super_output_accuracy: 0.9180 - sub_output_accuracy: 0.5432 - val_loss: 0.9949 - val_super_output_loss: 0.2548 - val_sub_output_loss: 1.4883 - val_super_output_accuracy: 0.8926 - val_sub_output_accuracy: 0.4625
# Epoch 13/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.8080 - super_output_loss: 0.1970 - sub_output_loss: 1.2154 - super_output_accuracy: 0.9232 - sub_output_accuracy: 0.5587 - val_loss: 0.9756 - val_super_output_loss: 0.2490 - val_sub_output_loss: 1.4601 - val_super_output_accuracy: 0.8948 - val_sub_output_accuracy: 0.4669
# Epoch 14/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.7752 - super_output_loss: 0.1887 - sub_output_loss: 1.1662 - super_output_accuracy: 0.9268 - sub_output_accuracy: 0.5746 - val_loss: 0.8672 - val_super_output_loss: 0.2238 - val_sub_output_loss: 1.2960 - val_super_output_accuracy: 0.9077 - val_sub_output_accuracy: 0.5261
# Epoch 15/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.7504 - super_output_loss: 0.1841 - sub_output_loss: 1.1279 - super_output_accuracy: 0.9262 - sub_output_accuracy: 0.5957 - val_loss: 0.8907 - val_super_output_loss: 0.2378 - val_sub_output_loss: 1.3260 - val_super_output_accuracy: 0.9012 - val_sub_output_accuracy: 0.5187
# Epoch 16/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.7207 - super_output_loss: 0.1735 - sub_output_loss: 1.0855 - super_output_accuracy: 0.9328 - sub_output_accuracy: 0.6130 - val_loss: 0.8516 - val_super_output_loss: 0.2120 - val_sub_output_loss: 1.2780 - val_super_output_accuracy: 0.9166 - val_sub_output_accuracy: 0.5400
# Epoch 17/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.6977 - super_output_loss: 0.1670 - sub_output_loss: 1.0514 - super_output_accuracy: 0.9357 - sub_output_accuracy: 0.6225 - val_loss: 0.7903 - val_super_output_loss: 0.1992 - val_sub_output_loss: 1.1844 - val_super_output_accuracy: 0.9209 - val_sub_output_accuracy: 0.5694
# Epoch 18/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.6712 - super_output_loss: 0.1589 - sub_output_loss: 1.0127 - super_output_accuracy: 0.9400 - sub_output_accuracy: 0.6391 - val_loss: 0.7735 - val_super_output_loss: 0.1850 - val_sub_output_loss: 1.1659 - val_super_output_accuracy: 0.9274 - val_sub_output_accuracy: 0.5791
# Epoch 19/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.6456 - super_output_loss: 0.1521 - sub_output_loss: 0.9746 - super_output_accuracy: 0.9431 - sub_output_accuracy: 0.6489 - val_loss: 0.7701 - val_super_output_loss: 0.1990 - val_sub_output_loss: 1.1508 - val_super_output_accuracy: 0.9230 - val_sub_output_accuracy: 0.5884
# Epoch 20/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.6302 - super_output_loss: 0.1510 - sub_output_loss: 0.9497 - super_output_accuracy: 0.9431 - sub_output_accuracy: 0.6637 - val_loss: 0.7369 - val_super_output_loss: 0.1857 - val_sub_output_loss: 1.1043 - val_super_output_accuracy: 0.9273 - val_sub_output_accuracy: 0.6066
# Epoch 21/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.6125 - super_output_loss: 0.1392 - sub_output_loss: 0.9280 - super_output_accuracy: 0.9463 - sub_output_accuracy: 0.6676 - val_loss: 0.7181 - val_super_output_loss: 0.1803 - val_sub_output_loss: 1.0766 - val_super_output_accuracy: 0.9291 - val_sub_output_accuracy: 0.6216
# Epoch 22/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.5956 - super_output_loss: 0.1400 - sub_output_loss: 0.8994 - super_output_accuracy: 0.9481 - sub_output_accuracy: 0.6819 - val_loss: 0.6684 - val_super_output_loss: 0.1600 - val_sub_output_loss: 1.0073 - val_super_output_accuracy: 0.9374 - val_sub_output_accuracy: 0.6416
# Epoch 23/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.5754 - super_output_loss: 0.1298 - sub_output_loss: 0.8724 - super_output_accuracy: 0.9504 - sub_output_accuracy: 0.6905 - val_loss: 0.6933 - val_super_output_loss: 0.1615 - val_sub_output_loss: 1.0479 - val_super_output_accuracy: 0.9364 - val_sub_output_accuracy: 0.6262
# Epoch 24/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.5573 - super_output_loss: 0.1254 - sub_output_loss: 0.8452 - super_output_accuracy: 0.9527 - sub_output_accuracy: 0.7028 - val_loss: 0.7849 - val_super_output_loss: 0.1716 - val_sub_output_loss: 1.1938 - val_super_output_accuracy: 0.9333 - val_sub_output_accuracy: 0.5908
# Epoch 25/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.5396 - super_output_loss: 0.1237 - sub_output_loss: 0.8168 - super_output_accuracy: 0.9537 - sub_output_accuracy: 0.7119 - val_loss: 0.6225 - val_super_output_loss: 0.1386 - val_sub_output_loss: 0.9451 - val_super_output_accuracy: 0.9476 - val_sub_output_accuracy: 0.6633
# Epoch 26/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.5267 - super_output_loss: 0.1193 - sub_output_loss: 0.7983 - super_output_accuracy: 0.9552 - sub_output_accuracy: 0.7209 - val_loss: 0.6157 - val_super_output_loss: 0.1511 - val_sub_output_loss: 0.9255 - val_super_output_accuracy: 0.9438 - val_sub_output_accuracy: 0.6742
# Epoch 27/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.5097 - super_output_loss: 0.1106 - sub_output_loss: 0.7757 - super_output_accuracy: 0.9597 - sub_output_accuracy: 0.7242 - val_loss: 0.6307 - val_super_output_loss: 0.1573 - val_sub_output_loss: 0.9463 - val_super_output_accuracy: 0.9399 - val_sub_output_accuracy: 0.6675
# Epoch 28/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.4908 - super_output_loss: 0.1030 - sub_output_loss: 0.7494 - super_output_accuracy: 0.9613 - sub_output_accuracy: 0.7374 - val_loss: 0.6279 - val_super_output_loss: 0.1389 - val_sub_output_loss: 0.9539 - val_super_output_accuracy: 0.9468 - val_sub_output_accuracy: 0.6688
# Epoch 29/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.4732 - super_output_loss: 0.1010 - sub_output_loss: 0.7213 - super_output_accuracy: 0.9635 - sub_output_accuracy: 0.7437 - val_loss: 0.6162 - val_super_output_loss: 0.1528 - val_sub_output_loss: 0.9251 - val_super_output_accuracy: 0.9425 - val_sub_output_accuracy: 0.6797
# Epoch 30/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.4625 - super_output_loss: 0.0992 - sub_output_loss: 0.7047 - super_output_accuracy: 0.9630 - sub_output_accuracy: 0.7548 - val_loss: 0.5821 - val_super_output_loss: 0.1394 - val_sub_output_loss: 0.8772 - val_super_output_accuracy: 0.9500 - val_sub_output_accuracy: 0.6963
# Epoch 31/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.4493 - super_output_loss: 0.0950 - sub_output_loss: 0.6855 - super_output_accuracy: 0.9658 - sub_output_accuracy: 0.7558 - val_loss: 0.5783 - val_super_output_loss: 0.1324 - val_sub_output_loss: 0.8756 - val_super_output_accuracy: 0.9504 - val_sub_output_accuracy: 0.6991
# Epoch 32/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.4377 - super_output_loss: 0.0936 - sub_output_loss: 0.6671 - super_output_accuracy: 0.9641 - sub_output_accuracy: 0.7662 - val_loss: 0.5756 - val_super_output_loss: 0.1313 - val_sub_output_loss: 0.8717 - val_super_output_accuracy: 0.9495 - val_sub_output_accuracy: 0.7007
# Epoch 33/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.4216 - super_output_loss: 0.0826 - sub_output_loss: 0.6477 - super_output_accuracy: 0.9693 - sub_output_accuracy: 0.7741 - val_loss: 0.5846 - val_super_output_loss: 0.1297 - val_sub_output_loss: 0.8878 - val_super_output_accuracy: 0.9540 - val_sub_output_accuracy: 0.6953
# Epoch 34/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.4098 - super_output_loss: 0.0806 - sub_output_loss: 0.6293 - super_output_accuracy: 0.9700 - sub_output_accuracy: 0.7789 - val_loss: 0.5423 - val_super_output_loss: 0.1259 - val_sub_output_loss: 0.8200 - val_super_output_accuracy: 0.9549 - val_sub_output_accuracy: 0.7167
# Epoch 35/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3936 - super_output_loss: 0.0781 - sub_output_loss: 0.6040 - super_output_accuracy: 0.9718 - sub_output_accuracy: 0.7864 - val_loss: 0.5738 - val_super_output_loss: 0.1409 - val_sub_output_loss: 0.8625 - val_super_output_accuracy: 0.9479 - val_sub_output_accuracy: 0.7056
# Epoch 36/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3827 - super_output_loss: 0.0749 - sub_output_loss: 0.5879 - super_output_accuracy: 0.9718 - sub_output_accuracy: 0.7928 - val_loss: 0.5836 - val_super_output_loss: 0.1402 - val_sub_output_loss: 0.8792 - val_super_output_accuracy: 0.9515 - val_sub_output_accuracy: 0.7053
# Epoch 37/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3762 - super_output_loss: 0.0756 - sub_output_loss: 0.5766 - super_output_accuracy: 0.9720 - sub_output_accuracy: 0.7995 - val_loss: 0.5530 - val_super_output_loss: 0.1347 - val_sub_output_loss: 0.8319 - val_super_output_accuracy: 0.9516 - val_sub_output_accuracy: 0.7151
# Epoch 38/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3641 - super_output_loss: 0.0721 - sub_output_loss: 0.5587 - super_output_accuracy: 0.9745 - sub_output_accuracy: 0.8053 - val_loss: 0.5439 - val_super_output_loss: 0.1338 - val_sub_output_loss: 0.8173 - val_super_output_accuracy: 0.9533 - val_sub_output_accuracy: 0.7208
# Epoch 39/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3523 - super_output_loss: 0.0656 - sub_output_loss: 0.5433 - super_output_accuracy: 0.9761 - sub_output_accuracy: 0.8095 - val_loss: 0.5187 - val_super_output_loss: 0.1264 - val_sub_output_loss: 0.7803 - val_super_output_accuracy: 0.9547 - val_sub_output_accuracy: 0.7372
# Epoch 40/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3369 - super_output_loss: 0.0610 - sub_output_loss: 0.5209 - super_output_accuracy: 0.9780 - sub_output_accuracy: 0.8175 - val_loss: 0.5476 - val_super_output_loss: 0.1381 - val_sub_output_loss: 0.8205 - val_super_output_accuracy: 0.9498 - val_sub_output_accuracy: 0.7236
# Epoch 41/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3244 - super_output_loss: 0.0565 - sub_output_loss: 0.5029 - super_output_accuracy: 0.9798 - sub_output_accuracy: 0.8238 - val_loss: 0.5728 - val_super_output_loss: 0.1315 - val_sub_output_loss: 0.8670 - val_super_output_accuracy: 0.9564 - val_sub_output_accuracy: 0.7140
# Epoch 42/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3170 - super_output_loss: 0.0576 - sub_output_loss: 0.4899 - super_output_accuracy: 0.9797 - sub_output_accuracy: 0.8305 - val_loss: 0.5194 - val_super_output_loss: 0.1301 - val_sub_output_loss: 0.7790 - val_super_output_accuracy: 0.9556 - val_sub_output_accuracy: 0.7413
# Epoch 43/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.3127 - super_output_loss: 0.0564 - sub_output_loss: 0.4836 - super_output_accuracy: 0.9800 - sub_output_accuracy: 0.8284 - val_loss: 0.5385 - val_super_output_loss: 0.1290 - val_sub_output_loss: 0.8114 - val_super_output_accuracy: 0.9571 - val_sub_output_accuracy: 0.7352
# Epoch 44/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.2988 - super_output_loss: 0.0518 - sub_output_loss: 0.4634 - super_output_accuracy: 0.9816 - sub_output_accuracy: 0.8375 - val_loss: 0.5660 - val_super_output_loss: 0.1650 - val_sub_output_loss: 0.8333 - val_super_output_accuracy: 0.9455 - val_sub_output_accuracy: 0.7309
# Epoch 45/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.2914 - super_output_loss: 0.0504 - sub_output_loss: 0.4520 - super_output_accuracy: 0.9819 - sub_output_accuracy: 0.8400 - val_loss: 0.5296 - val_super_output_loss: 0.1379 - val_sub_output_loss: 0.7907 - val_super_output_accuracy: 0.9554 - val_sub_output_accuracy: 0.7423
# Epoch 46/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.2733 - super_output_loss: 0.0450 - sub_output_loss: 0.4255 - super_output_accuracy: 0.9843 - sub_output_accuracy: 0.8506 - val_loss: 0.5402 - val_super_output_loss: 0.1333 - val_sub_output_loss: 0.8115 - val_super_output_accuracy: 0.9579 - val_sub_output_accuracy: 0.7381
# Epoch 47/65
# 79/79 [==============================] - 6s 70ms/step - loss: 0.2658 - super_output_loss: 0.0457 - sub_output_loss: 0.4125 - super_output_accuracy: 0.9840 - sub_output_accuracy: 0.8561 - val_loss: 0.5371 - val_super_output_loss: 0.1373 - val_sub_output_loss: 0.8036 - val_super_output_accuracy: 0.9563 - val_sub_output_accuracy: 0.7392
# Epoch 48/65
# 79/79 [==============================] - 5s 69ms/step - loss: 0.2619 - super_output_loss: 0.0442 - sub_output_loss: 0.4071 - super_output_accuracy: 0.9849 - sub_output_accuracy: 0.8543 - val_loss: 0.5095 - val_super_output_loss: 0.1284 - val_sub_output_loss: 0.7635 - val_super_output_accuracy: 0.9595 - val_sub_output_accuracy: 0.7561
# Epoch 49/65
# 79/79 [==============================] - 5s 69ms/step - loss: 0.2502 - super_output_loss: 0.0415 - sub_output_loss: 0.3893 - super_output_accuracy: 0.9854 - sub_output_accuracy: 0.8657 - val_loss: 0.5159 - val_super_output_loss: 0.1246 - val_sub_output_loss: 0.7768 - val_super_output_accuracy: 0.9610 - val_sub_output_accuracy: 0.7497
# Epoch 50/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.2385 - super_output_loss: 0.0400 - sub_output_loss: 0.3708 - super_output_accuracy: 0.9853 - sub_output_accuracy: 0.8712 - val_loss: 0.5413 - val_super_output_loss: 0.1492 - val_sub_output_loss: 0.8027 - val_super_output_accuracy: 0.9542 - val_sub_output_accuracy: 0.7518
# Epoch 51/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.2335 - super_output_loss: 0.0357 - sub_output_loss: 0.3654 - super_output_accuracy: 0.9871 - sub_output_accuracy: 0.8714 - val_loss: 0.5887 - val_super_output_loss: 0.1738 - val_sub_output_loss: 0.8653 - val_super_output_accuracy: 0.9498 - val_sub_output_accuracy: 0.7371
# Epoch 52/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.2276 - super_output_loss: 0.0366 - sub_output_loss: 0.3550 - super_output_accuracy: 0.9862 - sub_output_accuracy: 0.8737 - val_loss: 0.5756 - val_super_output_loss: 0.1450 - val_sub_output_loss: 0.8626 - val_super_output_accuracy: 0.9569 - val_sub_output_accuracy: 0.7401
# Epoch 53/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.2202 - super_output_loss: 0.0351 - sub_output_loss: 0.3436 - super_output_accuracy: 0.9878 - sub_output_accuracy: 0.8817 - val_loss: 0.5275 - val_super_output_loss: 0.1310 - val_sub_output_loss: 0.7917 - val_super_output_accuracy: 0.9608 - val_sub_output_accuracy: 0.7577
# Epoch 54/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.2094 - super_output_loss: 0.0341 - sub_output_loss: 0.3262 - super_output_accuracy: 0.9878 - sub_output_accuracy: 0.8840 - val_loss: 0.5515 - val_super_output_loss: 0.1540 - val_sub_output_loss: 0.8164 - val_super_output_accuracy: 0.9552 - val_sub_output_accuracy: 0.7513
# Epoch 55/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.2042 - super_output_loss: 0.0319 - sub_output_loss: 0.3191 - super_output_accuracy: 0.9885 - sub_output_accuracy: 0.8876 - val_loss: 0.5460 - val_super_output_loss: 0.1403 - val_sub_output_loss: 0.8164 - val_super_output_accuracy: 0.9585 - val_sub_output_accuracy: 0.7513
# Epoch 56/65
# 79/79 [==============================] - 5s 65ms/step - loss: 0.1973 - super_output_loss: 0.0317 - sub_output_loss: 0.3078 - super_output_accuracy: 0.9896 - sub_output_accuracy: 0.8929 - val_loss: 0.5537 - val_super_output_loss: 0.1533 - val_sub_output_loss: 0.8206 - val_super_output_accuracy: 0.9566 - val_sub_output_accuracy: 0.7576
# Epoch 57/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.1876 - super_output_loss: 0.0304 - sub_output_loss: 0.2924 - super_output_accuracy: 0.9894 - sub_output_accuracy: 0.8983 - val_loss: 0.5520 - val_super_output_loss: 0.1483 - val_sub_output_loss: 0.8211 - val_super_output_accuracy: 0.9573 - val_sub_output_accuracy: 0.7545
# Epoch 58/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.1803 - super_output_loss: 0.0293 - sub_output_loss: 0.2811 - super_output_accuracy: 0.9894 - sub_output_accuracy: 0.9019 - val_loss: 0.5530 - val_super_output_loss: 0.1592 - val_sub_output_loss: 0.8155 - val_super_output_accuracy: 0.9566 - val_sub_output_accuracy: 0.7578
# Epoch 59/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.1818 - super_output_loss: 0.0301 - sub_output_loss: 0.2829 - super_output_accuracy: 0.9897 - sub_output_accuracy: 0.9001 - val_loss: 0.5646 - val_super_output_loss: 0.1627 - val_sub_output_loss: 0.8325 - val_super_output_accuracy: 0.9548 - val_sub_output_accuracy: 0.7580
# Epoch 60/65
# 79/79 [==============================] - 5s 67ms/step - loss: 0.1674 - super_output_loss: 0.0282 - sub_output_loss: 0.2602 - super_output_accuracy: 0.9902 - sub_output_accuracy: 0.9108 - val_loss: 0.5504 - val_super_output_loss: 0.1376 - val_sub_output_loss: 0.8256 - val_super_output_accuracy: 0.9603 - val_sub_output_accuracy: 0.7578
# Epoch 61/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.1666 - super_output_loss: 0.0280 - sub_output_loss: 0.2591 - super_output_accuracy: 0.9899 - sub_output_accuracy: 0.9090 - val_loss: 0.5999 - val_super_output_loss: 0.1698 - val_sub_output_loss: 0.8867 - val_super_output_accuracy: 0.9539 - val_sub_output_accuracy: 0.7530
# Epoch 62/65
# 79/79 [==============================] - 5s 69ms/step - loss: 0.1610 - super_output_loss: 0.0272 - sub_output_loss: 0.2502 - super_output_accuracy: 0.9909 - sub_output_accuracy: 0.9123 - val_loss: 0.5866 - val_super_output_loss: 0.1500 - val_sub_output_loss: 0.8776 - val_super_output_accuracy: 0.9591 - val_sub_output_accuracy: 0.7532
# Epoch 63/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.1555 - super_output_loss: 0.0223 - sub_output_loss: 0.2443 - super_output_accuracy: 0.9926 - sub_output_accuracy: 0.9142 - val_loss: 0.5417 - val_super_output_loss: 0.1491 - val_sub_output_loss: 0.8034 - val_super_output_accuracy: 0.9581 - val_sub_output_accuracy: 0.7728
# Epoch 64/65
# 79/79 [==============================] - 5s 68ms/step - loss: 0.1478 - super_output_loss: 0.0218 - sub_output_loss: 0.2317 - super_output_accuracy: 0.9924 - sub_output_accuracy: 0.9211 - val_loss: 0.5599 - val_super_output_loss: 0.1406 - val_sub_output_loss: 0.8394 - val_super_output_accuracy: 0.9612 - val_sub_output_accuracy: 0.7643
# Epoch 65/65
# 79/79 [==============================] - 5s 66ms/step - loss: 0.1383 - super_output_loss: 0.0201 - sub_output_loss: 0.2171 - super_output_accuracy: 0.9926 - sub_output_accuracy: 0.9263 - val_loss: 0.5945 - val_super_output_loss: 0.1682 - val_sub_output_loss: 0.8788 - val_super_output_accuracy: 0.9558 - val_sub_output_accuracy: 0.7620

# %%
yhat_super_test, yhat_sub_test = model.predict(x_test, use_multiprocessing=True)

# %%
y_super, yhat_super = v_get_labels(np.argmax(y_super_test, axis=1), 'super'), v_get_labels(np.argmax(yhat_super_test, axis=1), 'super')
y_sub, yhat_sub = v_get_labels(np.argmax(y_sub_test, axis=1),'sub'), v_get_labels(np.argmax(yhat_sub_test, axis=1),'sub')

# %%
pd.crosstab(y_super, yhat_super, rownames=['Actual'], colnames=['Pred'])
# Out:
# Pred     animal  machine
# Actual
# animal     5882      118
# machine     280     3720

# %%
pd.crosstab(y_sub, yhat_sub, rownames=['Actual'], colnames=['Pred'])
# Out:
# Pred        airplane  automobile  bird  cat  deer  dog  frog  horse  ship  \
# Actual
# airplane         806          12    30   30    16   15     7      3    54
# automobile        25         841     3   19     3    9    10      4    26
# bird              49           1   640   77    88   87    41      7     8
# cat               12           2    40  634    50  195    50      9     4
# deer              10           1    51   78   764   46    28     16     6
# dog                5           0    30  148    42  752    12      9     1
# frog               6           1    27   82    28   32   820      2     1
# horse             11           1    18   68   103  128     7    663     0
# ship              43          14     8   28     5   12     4      1   875
# truck             30          53     6   29     4   14     8      7    33
#
# Pred        truck
# Actual
# airplane       27
# automobile     60
# bird            2
# cat             4
# deer            0
# dog             1
# frog            1
# horse           1
# ship           10
# truck         816

# %%
def calculate_hiearchy_mismatch(super_labels, sub_labels, hierarchy):
    mismatch = 0
    assert len(super_labels) == len(sub_labels)
    for idx, super_label in enumerate(super_labels):
        if sub_labels[idx] not in hierarchy[super_label]:
            mismatch += 1
    return mismatch

# %%
n_rows = len(x_test)
error_rate_super = sum(y_super != yhat_super) / n_rows
error_rate_sub = sum(y_sub != yhat_sub) / n_rows

hierarchy = gen_hierarchy(y_super_train, y_sub_train)
n_mismatch = calculate_hiearchy_mismatch(np.argmax(yhat_super_test, axis=1), np.argmax(yhat_sub_test, axis=1), hierarchy)
mismatch_rate = n_mismatch / n_rows

print(f"Super Class Error Rate: {error_rate_super}\nSub Class Error Rate: {error_rate_sub}\nMismatch Rate: {mismatch_rate}")
# Out:
# Super Class Error Rate: 0.0398
# Sub Class Error Rate: 0.2389
# Mismatch Rate: 0.0075

# %%
yhat_super_train, yhat_sub_train = model.predict(x = x_train, use_multiprocessing=True)

y_super, yhat_super = v_get_labels(np.argmax(y_super_train, axis=1), 'super'), v_get_labels(np.argmax(yhat_super_train, axis=1), 'super')
y_sub, yhat_sub = v_get_labels(np.argmax(y_sub_train, axis=1),'sub'), v_get_labels(np.argmax(yhat_sub_train, axis=1),'sub')

n_rows = len(x_train)
error_rate_super = sum(y_super != yhat_super) / n_rows
error_rate_sub = sum(y_sub != yhat_sub) / n_rows

hierarchy = gen_hierarchy(y_super_train, y_sub_train)
n_mismatch = calculate_hiearchy_mismatch(np.argmax(yhat_super_train, axis=1), np.argmax(yhat_sub_train, axis=1), hierarchy)
mismatch_rate = n_mismatch / n_rows

print(f"Super Class Error Rate: {error_rate_super}\nSub Class Error Rate: {error_rate_sub}\nMismatch Rate: {mismatch_rate}")
# Out:
# Super Class Error Rate: 0.0131
# Sub Class Error Rate: 0.0878
# Mismatch Rate: 0.0032
