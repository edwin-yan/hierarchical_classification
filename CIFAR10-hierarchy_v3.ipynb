# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D, BatchNormalization, Activation, Dropout
from tensorflow.keras.utils import to_categorical
import tensorboard
import numpy as np
import logging
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd

# %%
physical_devices = tf.config.list_physical_devices('GPU')
for device in physical_devices:
    try:
        tf.config.experimental.set_memory_growth(device, True)
    except:
        pass

logging.getLogger().setLevel(logging.INFO)

# %%
def get_cifar10():
    def create_superclass(x):
        return 0 if x in [0, 1, 8, 9] else 1
    v_create_superclass = np.vectorize(create_superclass)
    
    (x_train, y_sub_train), (x_test, y_sub_test) = keras.datasets.cifar10.load_data()
    x_train, x_test = x_train / 255, x_test / 255
    y_super_train, y_super_test = to_categorical(v_create_superclass(y_sub_train)), to_categorical(v_create_superclass(y_sub_test))
    y_sub_train, y_sub_test = to_categorical(y_sub_train), to_categorical(y_sub_test)
    
    return (x_train, y_super_train, y_sub_train), (x_test, y_super_test, y_sub_test)

# %%
def get_cifar10():
    def create_superclass(x):
        return 0 if x in [0, 1, 8, 9] else 1
    v_create_superclass = np.vectorize(create_superclass)
    
    (x_train, y_sub_train), (x_test, y_sub_test) = keras.datasets.cifar10.load_data()
    x_train, x_test = x_train / 255, x_test / 255
    y_super_train, y_super_test = to_categorical(v_create_superclass(y_sub_train)), to_categorical(v_create_superclass(y_sub_test))
    y_sub_train, y_sub_test = to_categorical(y_sub_train), to_categorical(y_sub_test)
    
    return (x_train, y_super_train, y_sub_train), (x_test, y_super_test, y_sub_test)

# %%
def get_labels(idx, level = 'super'):
    labels = {
        'super':['machine', 'animal'],
        'sub': ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
    }
    return labels[level][idx]

v_get_labels = np.vectorize(get_labels)

# %%
def plot_sample_images(inputs, v_label_func, top_n = 20, n_col = 10):
    (images, super_labels_idx, sub_labels_idx) = inputs
    assert len(images) == len(super_labels_idx) == len(sub_labels_idx)
    super_labels, sub_labels = v_label_func(np.argmax(super_labels_idx, axis = 1), 'super'),  v_label_func(np.argmax(sub_labels_idx, axis = 1), 'sub')
    top_n = top_n if top_n < len(images) else len(images)
    n_row = int(top_n/n_col)
    images = images[:top_n]
    figsize = (2.5 * n_col, 2.5 * n_row)
    fig, axes = plt.subplots(n_row, n_col, figsize = figsize)
    for idx, image in enumerate(images):
        ax = axes[idx // n_col, idx % n_col]
        ax.imshow(image)
        ax.set_title(f"{super_labels[idx]} - {sub_labels[idx]}")
    plt.tight_layout()
    plt.show()

# %%
(x_train, y_super_train, y_sub_train), (x_test, y_super_test, y_sub_test) = get_cifar10()
plot_sample_images((x_train, y_super_train, y_sub_train), v_get_labels)

# %%
def gen_hierarchy(super_label, sub_label, use_argmax = False):
    combined_labels = np.stack((np.argmax(super_label, axis = 1), np.argmax(sub_label, axis = 1)), axis = 1)
    unique_combinations = np.unique(combined_labels, axis = 0)
    hierarchy={}
    for combination in unique_combinations:
        super_class, sub_class = combination
        if super_class in hierarchy.keys():
            hierarchy[super_class].append(sub_class)
        else:
            hierarchy[super_class] = [sub_class]
    return hierarchy

# %%
def conv_block(units, kernel_size = (3,3), stride=(1, 1), dropout=0.2, activation='relu', block=1, layer=1, class_type='default'):

    def layer_wrapper(inp):
        x = Conv2D(units, kernel_size, padding='same', name=f'{class_type}_block{block}_conv{layer}')(inp)
        x = Activation(activation, name=f'{class_type}_block{block}_act{layer}')(x)
        x = Dropout(dropout, name=f'{class_type}_block{block}_dropout{layer}')(x)
        x = BatchNormalization(name=f'{class_type}_block{block}_bn{layer}')(x)
        return x
    return layer_wrapper

def dense_block(units, dropout=0.2, activation='relu', name='default_fc1'):
    def layer_wrapper(inp):
        x = Dense(units, name=name)(inp)
#         x = BatchNormalization(name='{}_bn'.format(name))(x)
        x = Activation(activation, name='{}_act'.format(name))(x)
        x = Dropout(dropout, name='{}_dropout'.format(name))(x)
        return x
    return layer_wrapper



def create_base_layer(img_input, conv_dropout=0.1, fc_dropout=0.3, activation='relu', class_type = 'default', nodes = 64):
    
    # Block 1
    block = 1
    x = conv_block(nodes, kernel_size = (5, 5),dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(img_input)
    x = conv_block(nodes, kernel_size = (5, 5),dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)
    
    # Block 2
    block += 1
    x = conv_block(nodes * 2, dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(x)
    x = conv_block(nodes * 2, dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)

    # Block 3
    block += 1
    x = conv_block(nodes * 4, dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(x)
    x = conv_block(nodes * 4, dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)

    # Block 4
    block += 1
    x = conv_block(nodes * 8, dropout=conv_dropout, activation=activation, block=block, layer=1, class_type=class_type)(x)
    x = conv_block(nodes * 8, dropout=conv_dropout, activation=activation, block=block, layer=2, class_type=class_type)(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name=f'{class_type}_block{block}_pool')(x)

    x = GlobalAveragePooling2D()(x)
    
    # FC Layers
    x = dense_block(nodes * 8, dropout=fc_dropout, activation=activation, name=f'{class_type}_fc1')(x)
    
    return x


def create_layer(img_input, n_classes, conv_dropout=0.1, fc_dropout=0.3, activation='relu', class_type = 'default', embedding = None, nodes = 64):
    x = dense_block(nodes * 4, dropout=fc_dropout, activation=activation, name=f'{class_type}_fc2')(img_input)
#     x = dense_block(nodes * 4, dropout=fc_dropout, activation=activation, name=f'{class_type}_fc3')(x)
    if embedding is not None:
        x = tf.keras.layers.Concatenate()([x, embedding])
    output = Dense(n_classes, activation='softmax', name=f'{class_type}_output')(x)
    return output, x

# %%
n_superclasses = 2
n_subclasses = 10
input_shape = x_train[0].shape

img_input = Input(shape=input_shape, name='input')

base_layer = create_base_layer(img_input,class_type = 'base')

nodes = 64
class_type = 'super'
super_layer_embedding = dense_block(nodes * 4, name=f'{class_type}_fc2')(base_layer)
super_layer_final = Dense(n_superclasses, name=f'{class_type}_final')(super_layer_embedding)
super_layer = Activation('softmax', name=f'{class_type}_output')(super_layer_final)

class_type = 'sub'
sub_layer_embedding = dense_block(nodes * 4, name=f'{class_type}_fc2')(base_layer)
sub_layer_embedding = tf.keras.layers.Concatenate()([sub_layer_embedding, super_layer_embedding])
sub_layer_final = Dense(n_subclasses, name=f'{class_type}_final')(sub_layer_embedding)
sub_layer = Activation('softmax', name=f'{class_type}_output')(sub_layer_final)

class_type = 'combination'
combination_layer = tf.keras.layers.Concatenate()([super_layer_final, sub_layer_final])
combination_layer = Dense(n_subclasses, activation='softmax', name=f'{class_type}_output')(combination_layer)


model = keras.Model(inputs=img_input,
             outputs = [super_layer, sub_layer, combination_layer],
             name="cifar10")

# %%
model.summary()
# Out:
# Model: "cifar10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# base_block1_conv1 (Conv2D)      (None, 32, 32, 64)   4864        input[0][0]
# __________________________________________________________________________________________________
# base_block1_act1 (Activation)   (None, 32, 32, 64)   0           base_block1_conv1[0][0]
# __________________________________________________________________________________________________
# base_block1_dropout1 (Dropout)  (None, 32, 32, 64)   0           base_block1_act1[0][0]
# __________________________________________________________________________________________________
# base_block1_bn1 (BatchNormaliza (None, 32, 32, 64)   256         base_block1_dropout1[0][0]
# __________________________________________________________________________________________________
# base_block1_conv2 (Conv2D)      (None, 32, 32, 64)   102464      base_block1_bn1[0][0]
# __________________________________________________________________________________________________
# base_block1_act2 (Activation)   (None, 32, 32, 64)   0           base_block1_conv2[0][0]
# __________________________________________________________________________________________________
# base_block1_dropout2 (Dropout)  (None, 32, 32, 64)   0           base_block1_act2[0][0]
# __________________________________________________________________________________________________
# base_block1_bn2 (BatchNormaliza (None, 32, 32, 64)   256         base_block1_dropout2[0][0]
# __________________________________________________________________________________________________
# base_block1_pool (MaxPooling2D) (None, 16, 16, 64)   0           base_block1_bn2[0][0]
# __________________________________________________________________________________________________
# base_block2_conv1 (Conv2D)      (None, 16, 16, 128)  73856       base_block1_pool[0][0]
# __________________________________________________________________________________________________
# base_block2_act1 (Activation)   (None, 16, 16, 128)  0           base_block2_conv1[0][0]
# __________________________________________________________________________________________________
# base_block2_dropout1 (Dropout)  (None, 16, 16, 128)  0           base_block2_act1[0][0]
# __________________________________________________________________________________________________
# base_block2_bn1 (BatchNormaliza (None, 16, 16, 128)  512         base_block2_dropout1[0][0]
# __________________________________________________________________________________________________
# base_block2_conv2 (Conv2D)      (None, 16, 16, 128)  147584      base_block2_bn1[0][0]
# __________________________________________________________________________________________________
# base_block2_act2 (Activation)   (None, 16, 16, 128)  0           base_block2_conv2[0][0]
# __________________________________________________________________________________________________
# base_block2_dropout2 (Dropout)  (None, 16, 16, 128)  0           base_block2_act2[0][0]
# __________________________________________________________________________________________________
# base_block2_bn2 (BatchNormaliza (None, 16, 16, 128)  512         base_block2_dropout2[0][0]
# __________________________________________________________________________________________________
# base_block2_pool (MaxPooling2D) (None, 8, 8, 128)    0           base_block2_bn2[0][0]
# __________________________________________________________________________________________________
# base_block3_conv1 (Conv2D)      (None, 8, 8, 256)    295168      base_block2_pool[0][0]
# __________________________________________________________________________________________________
# base_block3_act1 (Activation)   (None, 8, 8, 256)    0           base_block3_conv1[0][0]
# __________________________________________________________________________________________________
# base_block3_dropout1 (Dropout)  (None, 8, 8, 256)    0           base_block3_act1[0][0]
# __________________________________________________________________________________________________
# base_block3_bn1 (BatchNormaliza (None, 8, 8, 256)    1024        base_block3_dropout1[0][0]
# __________________________________________________________________________________________________
# base_block3_conv2 (Conv2D)      (None, 8, 8, 256)    590080      base_block3_bn1[0][0]
# __________________________________________________________________________________________________
# base_block3_act2 (Activation)   (None, 8, 8, 256)    0           base_block3_conv2[0][0]
# __________________________________________________________________________________________________
# base_block3_dropout2 (Dropout)  (None, 8, 8, 256)    0           base_block3_act2[0][0]
# __________________________________________________________________________________________________
# base_block3_bn2 (BatchNormaliza (None, 8, 8, 256)    1024        base_block3_dropout2[0][0]
# __________________________________________________________________________________________________
# base_block3_pool (MaxPooling2D) (None, 4, 4, 256)    0           base_block3_bn2[0][0]
# __________________________________________________________________________________________________
# base_block4_conv1 (Conv2D)      (None, 4, 4, 512)    1180160     base_block3_pool[0][0]
# __________________________________________________________________________________________________
# base_block4_act1 (Activation)   (None, 4, 4, 512)    0           base_block4_conv1[0][0]
# __________________________________________________________________________________________________
# base_block4_dropout1 (Dropout)  (None, 4, 4, 512)    0           base_block4_act1[0][0]
# __________________________________________________________________________________________________
# base_block4_bn1 (BatchNormaliza (None, 4, 4, 512)    2048        base_block4_dropout1[0][0]
# __________________________________________________________________________________________________
# base_block4_conv2 (Conv2D)      (None, 4, 4, 512)    2359808     base_block4_bn1[0][0]
# __________________________________________________________________________________________________
# base_block4_act2 (Activation)   (None, 4, 4, 512)    0           base_block4_conv2[0][0]
# __________________________________________________________________________________________________
# base_block4_dropout2 (Dropout)  (None, 4, 4, 512)    0           base_block4_act2[0][0]
# __________________________________________________________________________________________________
# base_block4_bn2 (BatchNormaliza (None, 4, 4, 512)    2048        base_block4_dropout2[0][0]
# __________________________________________________________________________________________________
# base_block4_pool (MaxPooling2D) (None, 2, 2, 512)    0           base_block4_bn2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           base_block4_pool[0][0]
# __________________________________________________________________________________________________
# base_fc1 (Dense)                (None, 512)          262656      global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# base_fc1_act (Activation)       (None, 512)          0           base_fc1[0][0]
# __________________________________________________________________________________________________
# base_fc1_dropout (Dropout)      (None, 512)          0           base_fc1_act[0][0]
# __________________________________________________________________________________________________
# super_fc2 (Dense)               (None, 256)          131328      base_fc1_dropout[0][0]
# __________________________________________________________________________________________________
# sub_fc2 (Dense)                 (None, 256)          131328      base_fc1_dropout[0][0]
# __________________________________________________________________________________________________
# super_fc2_act (Activation)      (None, 256)          0           super_fc2[0][0]
# __________________________________________________________________________________________________
# sub_fc2_act (Activation)        (None, 256)          0           sub_fc2[0][0]
# __________________________________________________________________________________________________
# super_fc2_dropout (Dropout)     (None, 256)          0           super_fc2_act[0][0]
# __________________________________________________________________________________________________
# sub_fc2_dropout (Dropout)       (None, 256)          0           sub_fc2_act[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512)          0           sub_fc2_dropout[0][0]
#                                                                  super_fc2_dropout[0][0]
# __________________________________________________________________________________________________
# super_final (Dense)             (None, 2)            514         super_fc2_dropout[0][0]
# __________________________________________________________________________________________________
# sub_final (Dense)               (None, 10)           5130        concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           super_final[0][0]
#                                                                  sub_final[0][0]
# __________________________________________________________________________________________________
# super_output (Activation)       (None, 2)            0           super_final[0][0]
# __________________________________________________________________________________________________
# sub_output (Activation)         (None, 10)           0           sub_final[0][0]
# __________________________________________________________________________________________________
# combination_output (Dense)      (None, 10)           130         concatenate_1[0][0]
# ==================================================================================================
# Total params: 5,292,750
# Trainable params: 5,288,910
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=False, show_dtype=False, show_layer_names=True, rankdir='TB', expand_nested=False)

# %%
init_lr = 1e-4
epochs = 100
# super_weight_ratio = 0.3


opt = keras.optimizers.Adam(lr=init_lr, decay=init_lr / epochs)

model.compile(
    optimizer=opt,
    loss={
        'super_output':'categorical_crossentropy',
        'sub_output':'categorical_crossentropy',
        'combination_output': 'categorical_crossentropy',
    },
    metrics={
        'super_output':'accuracy',
        'sub_output':'accuracy',
        'combination_output':'accuracy',
    }, 
    loss_weights=[0.35, 0.5, 0.15]
)

# %%
logdir = "./logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")

# tensorboard_callback = keras.callbacks.TensorBoard(
#     log_dir=logdir,
#     histogram_freq=1
# )

earlystop_callback = keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-5,
    patience=15
)

# checkpoint_callbacks = [
#     keras.callbacks.ModelCheckpoint("./model_checkpoint", monitor='val_loss')
# ]

history = model.fit(
    x_train, 
    y={"super_output": y_super_train, "sub_output": y_sub_train, "combination_output":y_sub_train},
    validation_data=(x_test,{"super_output": y_super_test, "sub_output": y_sub_test, "combination_output": y_sub_test}),
    batch_size = 512,
    epochs=epochs,
    validation_split=0.2,
    use_multiprocessing=True,
    callbacks=[
#         tensorboard_callback,
        earlystop_callback
    ]
)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 20s 146ms/step - loss: 1.6386 - super_output_loss: 0.4828 - sub_output_loss: 2.1830 - combination_output_loss: 2.5208 - super_output_accuracy: 0.7694 - sub_output_accuracy: 0.2388 - combination_output_accuracy: 0.1475 - val_loss: 1.8769 - val_super_output_loss: 0.6872 - val_sub_output_loss: 2.5510 - val_combination_output_loss: 2.4061 - val_super_output_accuracy: 0.5947 - val_sub_output_accuracy: 0.0997 - val_combination_output_accuracy: 0.0997
# Epoch 2/100
# 79/79 [==============================] - 9s 114ms/step - loss: 1.2117 - super_output_loss: 0.2817 - sub_output_loss: 1.6159 - combination_output_loss: 2.0347 - super_output_accuracy: 0.8887 - sub_output_accuracy: 0.4180 - combination_output_accuracy: 0.2537 - val_loss: 2.2758 - val_super_output_loss: 0.7862 - val_sub_output_loss: 3.2056 - val_combination_output_loss: 2.6521 - val_super_output_accuracy: 0.5947 - val_sub_output_accuracy: 0.0997 - val_combination_output_accuracy: 0.0997
# Epoch 3/100
# 79/79 [==============================] - 9s 114ms/step - loss: 1.0943 - super_output_loss: 0.2471 - sub_output_loss: 1.4616 - combination_output_loss: 1.8465 - super_output_accuracy: 0.9038 - sub_output_accuracy: 0.4810 - combination_output_accuracy: 0.3238 - val_loss: 2.3137 - val_super_output_loss: 1.0247 - val_sub_output_loss: 3.1085 - val_combination_output_loss: 2.6722 - val_super_output_accuracy: 0.5947 - val_sub_output_accuracy: 0.0954 - val_combination_output_accuracy: 0.1009
# Epoch 4/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.9880 - super_output_loss: 0.2241 - sub_output_loss: 1.3313 - combination_output_loss: 1.6260 - super_output_accuracy: 0.9130 - sub_output_accuracy: 0.5267 - combination_output_accuracy: 0.4197 - val_loss: 2.2998 - val_super_output_loss: 1.1087 - val_sub_output_loss: 2.9968 - val_combination_output_loss: 2.7559 - val_super_output_accuracy: 0.5947 - val_sub_output_accuracy: 0.1186 - val_combination_output_accuracy: 0.1222
# Epoch 5/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.8940 - super_output_loss: 0.2003 - sub_output_loss: 1.2124 - combination_output_loss: 1.4511 - super_output_accuracy: 0.9225 - sub_output_accuracy: 0.5707 - combination_output_accuracy: 0.4968 - val_loss: 2.6786 - val_super_output_loss: 1.2189 - val_sub_output_loss: 3.5504 - val_combination_output_loss: 3.1782 - val_super_output_accuracy: 0.5949 - val_sub_output_accuracy: 0.0975 - val_combination_output_accuracy: 0.0970
# Epoch 6/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.8139 - super_output_loss: 0.1791 - sub_output_loss: 1.1121 - combination_output_loss: 1.3015 - super_output_accuracy: 0.9331 - sub_output_accuracy: 0.6128 - combination_output_accuracy: 0.5531 - val_loss: 2.6005 - val_super_output_loss: 1.4646 - val_sub_output_loss: 3.2451 - val_combination_output_loss: 3.1019 - val_super_output_accuracy: 0.6115 - val_sub_output_accuracy: 0.1770 - val_combination_output_accuracy: 0.1640
# Epoch 7/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.7672 - super_output_loss: 0.1696 - sub_output_loss: 1.0506 - combination_output_loss: 1.2172 - super_output_accuracy: 0.9363 - sub_output_accuracy: 0.6325 - combination_output_accuracy: 0.5860 - val_loss: 2.2548 - val_super_output_loss: 1.2026 - val_sub_output_loss: 2.8117 - val_combination_output_loss: 2.8532 - val_super_output_accuracy: 0.6834 - val_sub_output_accuracy: 0.2010 - val_combination_output_accuracy: 0.1922
# Epoch 8/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.6960 - super_output_loss: 0.1501 - sub_output_loss: 0.9555 - combination_output_loss: 1.1046 - super_output_accuracy: 0.9433 - sub_output_accuracy: 0.6686 - combination_output_accuracy: 0.6292 - val_loss: 1.5394 - val_super_output_loss: 0.5630 - val_sub_output_loss: 2.0458 - val_combination_output_loss: 2.1300 - val_super_output_accuracy: 0.8179 - val_sub_output_accuracy: 0.3655 - val_combination_output_accuracy: 0.3082
# Epoch 9/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.6416 - super_output_loss: 0.1339 - sub_output_loss: 0.8866 - combination_output_loss: 1.0098 - super_output_accuracy: 0.9509 - sub_output_accuracy: 0.6900 - combination_output_accuracy: 0.6544 - val_loss: 1.1406 - val_super_output_loss: 0.4272 - val_sub_output_loss: 1.4874 - val_combination_output_loss: 1.6491 - val_super_output_accuracy: 0.8567 - val_sub_output_accuracy: 0.4963 - val_combination_output_accuracy: 0.4580
# Epoch 10/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.5948 - super_output_loss: 0.1229 - sub_output_loss: 0.8223 - combination_output_loss: 0.9373 - super_output_accuracy: 0.9549 - sub_output_accuracy: 0.7115 - combination_output_accuracy: 0.6823 - val_loss: 0.9160 - val_super_output_loss: 0.1937 - val_sub_output_loss: 1.2861 - val_combination_output_loss: 1.3681 - val_super_output_accuracy: 0.9307 - val_sub_output_accuracy: 0.5653 - val_combination_output_accuracy: 0.5391
# Epoch 11/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.5607 - super_output_loss: 0.1111 - sub_output_loss: 0.7801 - combination_output_loss: 0.8781 - super_output_accuracy: 0.9576 - sub_output_accuracy: 0.7275 - combination_output_accuracy: 0.7013 - val_loss: 0.7757 - val_super_output_loss: 0.1830 - val_sub_output_loss: 1.0734 - val_combination_output_loss: 1.1661 - val_super_output_accuracy: 0.9355 - val_sub_output_accuracy: 0.6263 - val_combination_output_accuracy: 0.6024
# Epoch 12/100
# 79/79 [==============================] - 9s 115ms/step - loss: 0.5103 - super_output_loss: 0.0978 - sub_output_loss: 0.7114 - combination_output_loss: 0.8025 - super_output_accuracy: 0.9635 - sub_output_accuracy: 0.7527 - combination_output_accuracy: 0.7307 - val_loss: 0.6310 - val_super_output_loss: 0.1423 - val_sub_output_loss: 0.8835 - val_combination_output_loss: 0.9298 - val_super_output_accuracy: 0.9478 - val_sub_output_accuracy: 0.7030 - val_combination_output_accuracy: 0.6874
# Epoch 13/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.4740 - super_output_loss: 0.0909 - sub_output_loss: 0.6602 - combination_output_loss: 0.7473 - super_output_accuracy: 0.9654 - sub_output_accuracy: 0.7694 - combination_output_accuracy: 0.7462 - val_loss: 0.6444 - val_super_output_loss: 0.1803 - val_sub_output_loss: 0.8823 - val_combination_output_loss: 0.9342 - val_super_output_accuracy: 0.9376 - val_sub_output_accuracy: 0.7018 - val_combination_output_accuracy: 0.6913
# Epoch 14/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.4364 - super_output_loss: 0.0813 - sub_output_loss: 0.6089 - combination_output_loss: 0.6901 - super_output_accuracy: 0.9694 - sub_output_accuracy: 0.7899 - combination_output_accuracy: 0.7671 - val_loss: 0.5908 - val_super_output_loss: 0.1264 - val_sub_output_loss: 0.8377 - val_combination_output_loss: 0.8517 - val_super_output_accuracy: 0.9579 - val_sub_output_accuracy: 0.7256 - val_combination_output_accuracy: 0.7240
# Epoch 15/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.4082 - super_output_loss: 0.0754 - sub_output_loss: 0.5715 - combination_output_loss: 0.6404 - super_output_accuracy: 0.9718 - sub_output_accuracy: 0.7987 - combination_output_accuracy: 0.7819 - val_loss: 0.6178 - val_super_output_loss: 0.1326 - val_sub_output_loss: 0.8732 - val_combination_output_loss: 0.8982 - val_super_output_accuracy: 0.9587 - val_sub_output_accuracy: 0.7164 - val_combination_output_accuracy: 0.7044
# Epoch 16/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.3736 - super_output_loss: 0.0695 - sub_output_loss: 0.5215 - combination_output_loss: 0.5898 - super_output_accuracy: 0.9733 - sub_output_accuracy: 0.8180 - combination_output_accuracy: 0.8012 - val_loss: 0.6397 - val_super_output_loss: 0.1296 - val_sub_output_loss: 0.9108 - val_combination_output_loss: 0.9262 - val_super_output_accuracy: 0.9564 - val_sub_output_accuracy: 0.7137 - val_combination_output_accuracy: 0.7054
# Epoch 17/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.3462 - super_output_loss: 0.0589 - sub_output_loss: 0.4868 - combination_output_loss: 0.5477 - super_output_accuracy: 0.9783 - sub_output_accuracy: 0.8299 - combination_output_accuracy: 0.8178 - val_loss: 0.6017 - val_super_output_loss: 0.1647 - val_sub_output_loss: 0.8362 - val_combination_output_loss: 0.8393 - val_super_output_accuracy: 0.9525 - val_sub_output_accuracy: 0.7389 - val_combination_output_accuracy: 0.7347
# Epoch 18/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.3130 - super_output_loss: 0.0539 - sub_output_loss: 0.4402 - combination_output_loss: 0.4935 - super_output_accuracy: 0.9797 - sub_output_accuracy: 0.8476 - combination_output_accuracy: 0.8322 - val_loss: 0.5700 - val_super_output_loss: 0.1446 - val_sub_output_loss: 0.7980 - val_combination_output_loss: 0.8025 - val_super_output_accuracy: 0.9539 - val_sub_output_accuracy: 0.7476 - val_combination_output_accuracy: 0.7431
# Epoch 19/100
# 79/79 [==============================] - 9s 116ms/step - loss: 0.2967 - super_output_loss: 0.0477 - sub_output_loss: 0.4192 - combination_output_loss: 0.4698 - super_output_accuracy: 0.9832 - sub_output_accuracy: 0.8525 - combination_output_accuracy: 0.8380 - val_loss: 0.5327 - val_super_output_loss: 0.1258 - val_sub_output_loss: 0.7496 - val_combination_output_loss: 0.7595 - val_super_output_accuracy: 0.9609 - val_sub_output_accuracy: 0.7653 - val_combination_output_accuracy: 0.7610
# Epoch 20/100
# 79/79 [==============================] - 9s 113ms/step - loss: 0.2660 - super_output_loss: 0.0411 - sub_output_loss: 0.3755 - combination_output_loss: 0.4259 - super_output_accuracy: 0.9851 - sub_output_accuracy: 0.8680 - combination_output_accuracy: 0.8547 - val_loss: 0.6271 - val_super_output_loss: 0.1490 - val_sub_output_loss: 0.8821 - val_combination_output_loss: 0.8924 - val_super_output_accuracy: 0.9537 - val_sub_output_accuracy: 0.7305 - val_combination_output_accuracy: 0.7261
# Epoch 21/100
# 79/79 [==============================] - 9s 113ms/step - loss: 0.2460 - super_output_loss: 0.0368 - sub_output_loss: 0.3486 - combination_output_loss: 0.3920 - super_output_accuracy: 0.9852 - sub_output_accuracy: 0.8771 - combination_output_accuracy: 0.8656 - val_loss: 0.5958 - val_super_output_loss: 0.1331 - val_sub_output_loss: 0.8447 - val_combination_output_loss: 0.8454 - val_super_output_accuracy: 0.9600 - val_sub_output_accuracy: 0.7525 - val_combination_output_accuracy: 0.7462
# Epoch 22/100
# 79/79 [==============================] - 9s 116ms/step - loss: 0.2370 - super_output_loss: 0.0372 - sub_output_loss: 0.3346 - combination_output_loss: 0.3778 - super_output_accuracy: 0.9871 - sub_output_accuracy: 0.8829 - combination_output_accuracy: 0.8728 - val_loss: 0.6312 - val_super_output_loss: 0.1476 - val_sub_output_loss: 0.8905 - val_combination_output_loss: 0.8950 - val_super_output_accuracy: 0.9567 - val_sub_output_accuracy: 0.7478 - val_combination_output_accuracy: 0.7381
# Epoch 23/100
# 79/79 [==============================] - 9s 115ms/step - loss: 0.2140 - super_output_loss: 0.0342 - sub_output_loss: 0.3024 - combination_output_loss: 0.3390 - super_output_accuracy: 0.9876 - sub_output_accuracy: 0.8945 - combination_output_accuracy: 0.8825 - val_loss: 0.5818 - val_super_output_loss: 0.1365 - val_sub_output_loss: 0.8218 - val_combination_output_loss: 0.8206 - val_super_output_accuracy: 0.9611 - val_sub_output_accuracy: 0.7626 - val_combination_output_accuracy: 0.7554
# Epoch 24/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.2117 - super_output_loss: 0.0378 - sub_output_loss: 0.2968 - combination_output_loss: 0.3341 - super_output_accuracy: 0.9866 - sub_output_accuracy: 0.8967 - combination_output_accuracy: 0.8848 - val_loss: 0.5839 - val_super_output_loss: 0.1351 - val_sub_output_loss: 0.8280 - val_combination_output_loss: 0.8176 - val_super_output_accuracy: 0.9608 - val_sub_output_accuracy: 0.7645 - val_combination_output_accuracy: 0.7636
# Epoch 25/100
# 79/79 [==============================] - 9s 115ms/step - loss: 0.1745 - super_output_loss: 0.0260 - sub_output_loss: 0.2464 - combination_output_loss: 0.2811 - super_output_accuracy: 0.9904 - sub_output_accuracy: 0.9153 - combination_output_accuracy: 0.9037 - val_loss: 0.5793 - val_super_output_loss: 0.1387 - val_sub_output_loss: 0.8204 - val_combination_output_loss: 0.8039 - val_super_output_accuracy: 0.9640 - val_sub_output_accuracy: 0.7770 - val_combination_output_accuracy: 0.7725
# Epoch 26/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.1765 - super_output_loss: 0.0274 - sub_output_loss: 0.2499 - combination_output_loss: 0.2793 - super_output_accuracy: 0.9897 - sub_output_accuracy: 0.9153 - combination_output_accuracy: 0.9076 - val_loss: 0.5874 - val_super_output_loss: 0.1312 - val_sub_output_loss: 0.8411 - val_combination_output_loss: 0.8065 - val_super_output_accuracy: 0.9636 - val_sub_output_accuracy: 0.7755 - val_combination_output_accuracy: 0.7732
# Epoch 27/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.1409 - super_output_loss: 0.0209 - sub_output_loss: 0.1987 - combination_output_loss: 0.2279 - super_output_accuracy: 0.9923 - sub_output_accuracy: 0.9307 - combination_output_accuracy: 0.9242 - val_loss: 0.6407 - val_super_output_loss: 0.1414 - val_sub_output_loss: 0.9195 - val_combination_output_loss: 0.8765 - val_super_output_accuracy: 0.9632 - val_sub_output_accuracy: 0.7586 - val_combination_output_accuracy: 0.7583
# Epoch 28/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.1435 - super_output_loss: 0.0217 - sub_output_loss: 0.2031 - combination_output_loss: 0.2288 - super_output_accuracy: 0.9917 - sub_output_accuracy: 0.9292 - combination_output_accuracy: 0.9230 - val_loss: 0.6346 - val_super_output_loss: 0.1436 - val_sub_output_loss: 0.9100 - val_combination_output_loss: 0.8619 - val_super_output_accuracy: 0.9649 - val_sub_output_accuracy: 0.7724 - val_combination_output_accuracy: 0.7700
# Epoch 29/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.1209 - super_output_loss: 0.0177 - sub_output_loss: 0.1708 - combination_output_loss: 0.1949 - super_output_accuracy: 0.9938 - sub_output_accuracy: 0.9410 - combination_output_accuracy: 0.9344 - val_loss: 0.6442 - val_super_output_loss: 0.1675 - val_sub_output_loss: 0.9097 - val_combination_output_loss: 0.8720 - val_super_output_accuracy: 0.9605 - val_sub_output_accuracy: 0.7758 - val_combination_output_accuracy: 0.7719
# Epoch 30/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.1077 - super_output_loss: 0.0140 - sub_output_loss: 0.1528 - combination_output_loss: 0.1755 - super_output_accuracy: 0.9954 - sub_output_accuracy: 0.9460 - combination_output_accuracy: 0.9404 - val_loss: 0.6177 - val_super_output_loss: 0.1365 - val_sub_output_loss: 0.8841 - val_combination_output_loss: 0.8528 - val_super_output_accuracy: 0.9657 - val_sub_output_accuracy: 0.7821 - val_combination_output_accuracy: 0.7799
# Epoch 31/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.1045 - super_output_loss: 0.0163 - sub_output_loss: 0.1470 - combination_output_loss: 0.1688 - super_output_accuracy: 0.9942 - sub_output_accuracy: 0.9486 - combination_output_accuracy: 0.9434 - val_loss: 0.6540 - val_super_output_loss: 0.1538 - val_sub_output_loss: 0.9290 - val_combination_output_loss: 0.9042 - val_super_output_accuracy: 0.9638 - val_sub_output_accuracy: 0.7782 - val_combination_output_accuracy: 0.7727
# Epoch 32/100
# 79/79 [==============================] - 9s 115ms/step - loss: 0.0919 - super_output_loss: 0.0135 - sub_output_loss: 0.1292 - combination_output_loss: 0.1508 - super_output_accuracy: 0.9951 - sub_output_accuracy: 0.9572 - combination_output_accuracy: 0.9494 - val_loss: 0.7486 - val_super_output_loss: 0.2230 - val_sub_output_loss: 1.0361 - val_combination_output_loss: 1.0163 - val_super_output_accuracy: 0.9519 - val_sub_output_accuracy: 0.7601 - val_combination_output_accuracy: 0.7571
# Epoch 33/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.0880 - super_output_loss: 0.0123 - sub_output_loss: 0.1242 - combination_output_loss: 0.1440 - super_output_accuracy: 0.9959 - sub_output_accuracy: 0.9581 - combination_output_accuracy: 0.9517 - val_loss: 0.7437 - val_super_output_loss: 0.1701 - val_sub_output_loss: 1.0631 - val_combination_output_loss: 1.0173 - val_super_output_accuracy: 0.9633 - val_sub_output_accuracy: 0.7603 - val_combination_output_accuracy: 0.7596
# Epoch 34/100
# 79/79 [==============================] - 9s 114ms/step - loss: 0.0757 - super_output_loss: 0.0110 - sub_output_loss: 0.1068 - combination_output_loss: 0.1231 - super_output_accuracy: 0.9961 - sub_output_accuracy: 0.9633 - combination_output_accuracy: 0.9603 - val_loss: 0.7479 - val_super_output_loss: 0.1921 - val_sub_output_loss: 1.0577 - val_combination_output_loss: 1.0117 - val_super_output_accuracy: 0.9595 - val_sub_output_accuracy: 0.7700 - val_combination_output_accuracy: 0.7680

# %%
yhat_super_test, yhat_sub_test, _= model.predict(x_test, use_multiprocessing=True)

# %%
y_super, yhat_super = v_get_labels(np.argmax(y_super_test, axis=1), 'super'), v_get_labels(np.argmax(yhat_super_test, axis=1), 'super')
y_sub, yhat_sub = v_get_labels(np.argmax(y_sub_test, axis=1),'sub'), v_get_labels(np.argmax(yhat_sub_test, axis=1),'sub')

# %%
pd.crosstab(y_super, yhat_super, rownames=['Actual'], colnames=['Pred'])
# Out:
# Pred     animal  machine
# Actual
# animal     5736      264
# machine     175     3825

# %%
pd.crosstab(y_sub, yhat_sub, rownames=['Actual'], colnames=['Pred'])
# Out:
# Pred        airplane  automobile  bird  cat  deer  dog  frog  horse  ship  \
# Actual
# airplane         891           8     7    8    11    5     6     11    46
# automobile        38         833     3   11     5    4     5      5    30
# bird             112           0   547   86    78   89    52     26     9
# cat               38           1    19  613    41  223    37     18     5
# deer              29           1    36   79   727   51    32     38     7
# dog               22           1    15  145    30  748     8     29     1
# frog              17           1    13   71    25   55   813      2     2
# horse             22           1     6   36    56   59     2    814     0
# ship              68          16     6   10     6   11     5      0   870
# truck             65          39     2   22     2    7    10      4    33
#
# Pred        truck
# Actual
# airplane        7
# automobile     66
# bird            1
# cat             5
# deer            0
# dog             1
# frog            1
# horse           4
# ship            8
# truck         816

# %%
def calculate_hiearchy_mismatch(super_labels, sub_labels, hierarchy):
    mismatch = 0
    assert len(super_labels) == len(sub_labels)
    for idx, super_label in enumerate(super_labels):
        if sub_labels[idx] not in hierarchy[super_label]:
            mismatch += 1
    return mismatch

# %%
n_rows = len(x_test)
error_rate_super = sum(y_super != yhat_super) / n_rows
error_rate_sub = sum(y_sub != yhat_sub) / n_rows

hierarchy = gen_hierarchy(y_super_train, y_sub_train)
n_mismatch = calculate_hiearchy_mismatch(np.argmax(yhat_super_test, axis=1), np.argmax(yhat_sub_test, axis=1), hierarchy)
mismatch_rate = n_mismatch / n_rows

print(f"Super Class Error Rate: {error_rate_super}\nSub Class Error Rate: {error_rate_sub}\nMismatch Rate: {mismatch_rate}")
# Out:
# Super Class Error Rate: 0.0439
# Sub Class Error Rate: 0.2328
# Mismatch Rate: 0.01
